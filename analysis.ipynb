# %%
import json

with open("stock_data_examples/income_statement.json", "r") as file:
    income_statement = json.load(file)

# %%
# Only look for most recent 3 years & 10 quarters
income_statement['annualReports'] = income_statement['annualReports'][:3]
income_statement['quarterlyReports'] = income_statement['quarterlyReports'][:10]

# %%
with open("stock_data_examples/time_series_weekly.json", "r") as file:
    time_series_weekly = json.load(file)

# %%
with open("stock_data_examples/earnings.json", "r") as file:
    balance_sheet = json.load(file)

# %%
balance_sheet['quarterlyEarnings']
# Out:
# [{'fiscalDateEnding': '2024-04-30',
#   'reportedDate': '2024-05-22',
#   'reportedEPS': '6.12',
#   'estimatedEPS': '5.57',
#   'surprise': '0.55',
#   'surprisePercentage': '9.8743',
#   'reportTime': 'post-market'},
#  {'fiscalDateEnding': '2024-01-31',
#   'reportedDate': '2024-02-21',
#   'reportedEPS': '5.16',
#   'estimatedEPS': '4.29',
#   'surprise': '0.87',
#   'surprisePercentage': '20.2797',
#   'reportTime': 'post-market'},
#  {'fiscalDateEnding': '2023-10-31',
#   'reportedDate': '2023-11-21',
#   'reportedEPS': '4.02',
#   'estimatedEPS': '3.37',
#   'surprise': '0.65',
#   'surprisePercentage': '19.2878',
#   'reportTime': 'post-market'},
#  {'fiscalDateEnding': '2023-07-31',
#   'reportedDate': '2023-08-23',
#   'reportedEPS': '2.7',
#   'estimatedEPS': '2.09',
#   'surprise': '0.61',
#   'surprisePercentage': '29.1866',
#   'reportTime': 'post-market'},
#  {'fiscalDateEnding': '2023-04-30',
#   'reportedDate': '2023-05-24',
#   'reportedEPS': '1.09',
# ...
